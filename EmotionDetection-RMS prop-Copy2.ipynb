# %%
#!pip install keras
#!pip install tensorflow
#!pip install --upgrade keras tensorflow
#!pip install --upgrade opencv-python

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Flatten, Input
#from keras.optimizers import Adam
#from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers.schedules import ExponentialDecay
#import cv2
from keras.models import model_from_json
import numpy as np
from matplotlib import pyplot as plt

# %%
train_data_gen = ImageDataGenerator(rescale=1./255, 
                                    #rotation_range=30,
                                    #shear_range=0.3,
                                    #zoom_range=0.3,
                                    #horizontal_flip=True,
                                    #fill_mode='nearest'
                                   )
validation_data_gen = ImageDataGenerator(rescale=1./255, 
                                    #rotation_range=30,
                                    #shear_range=0.3,
                                    #zoom_range=0.3,
                                    #horizontal_flip=True,
                                    #fill_mode='nearest'
                                    )

train_generator = train_data_gen.flow_from_directory(
    'data/train',
    target_size=(48, 48),
    batch_size=32,
    color_mode="grayscale",
    class_mode='categorical')

validation_generator = validation_data_gen.flow_from_directory(
        'data/test',
        target_size=(48, 48),
        batch_size=32,
        color_mode="grayscale",
        class_mode='categorical')

total_train_samples = train_generator.n
total_validation_samples = validation_generator.n
batch_size = 32
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
emotion_model = Sequential()

emotion_model.add(Input(shape=(48,48,1)))

emotion_model.add(Conv2D(32, kernel_size=(5, 5), activation='relu'))
emotion_model.add(Conv2D(64, kernel_size=(5, 5), activation='relu'))
emotion_model.add(MaxPooling2D(pool_size=(2, 2)))
emotion_model.add(Dropout(0.25))
 
emotion_model.add(Conv2D(128, kernel_size=(5, 5), activation='relu'))
emotion_model.add(MaxPooling2D(pool_size=(2, 2)))
emotion_model.add(Conv2D(128, kernel_size=(5, 5), activation='relu'))
emotion_model.add(MaxPooling2D(pool_size=(2, 2)))
emotion_model.add(Dropout(0.25))
 
emotion_model.add(Flatten())
emotion_model.add(Dense(1024, activation='relu'))
emotion_model.add(Dropout(0.5))
emotion_model.add(Dense(7, activation='softmax'))
 
emotion_model.summary()
 
#cv2.ocl.setUseOpenCL(False)
 
initial_learning_rate = 0.001

lr_schedule = ExponentialDecay(initial_learning_rate, decay_steps=100000, 
                               decay_rate=0.96)
 
#optimizer = Adam(learning_rate=lr_schedule, amsgrad=True)
optimizer = RMSprop(learning_rate=initial_learning_rate)
 
emotion_model.compile(loss='categorical_crossentropy', optimizer=optimizer, 
                      metrics=['accuracy'])
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)                    │ (None, 44, 44, 32)          │             832 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 40, 40, 64)          │          51,264 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 20, 20, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 20, 20, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 16, 16, 128)         │         204,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 4, 4, 128)           │         409,728 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 2, 2, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 2, 2, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1024)                │         525,312 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 7)                   │           7,175 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,199,239 (4.57 MB)
#  Trainable params: 1,199,239 (4.57 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
emotion_model_info = emotion_model.fit(
    train_generator,
    steps_per_epoch=total_train_samples // batch_size,
    #epochs=30,
    epochs=50,
    validation_data=validation_generator,
    validation_steps=total_validation_samples // batch_size
)
# Out:
# Epoch 1/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 32s 34ms/step - accuracy: 0.2657 - loss: 1.7986 - val_accuracy: 0.3857 - val_loss: 1.5426
# Epoch 2/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 22us/step - accuracy: 0.4688 - loss: 0.7739 - val_accuracy: 0.3000 - val_loss: 0.8506
# Epoch 3/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 30s 34ms/step - accuracy: 0.4349 - loss: 1.4594 - val_accuracy: 0.5103 - val_loss: 1.2822
# Epoch 4/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 14us/step - accuracy: 0.4688 - loss: 0.6413 - val_accuracy: 0.5000 - val_loss: 0.7605
# Epoch 5/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 30s 34ms/step - accuracy: 0.4966 - loss: 1.3171 - val_accuracy: 0.5255 - val_loss: 1.2455
# Epoch 6/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 14us/step - accuracy: 0.7500 - loss: 0.5091 - val_accuracy: 0.6000 - val_loss: 0.5668
# Epoch 7/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 30s 33ms/step - accuracy: 0.5303 - loss: 1.2346 - val_accuracy: 0.5511 - val_loss: 1.1817
# Epoch 8/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 14us/step - accuracy: 0.3750 - loss: 0.7675 - val_accuracy: 0.5000 - val_loss: 0.6688
# Epoch 9/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 30s 33ms/step - accuracy: 0.5495 - loss: 1.1945 - val_accuracy: 0.5561 - val_loss: 1.2156
# Epoch 10/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 15us/step - accuracy: 0.5312 - loss: 0.5864 - val_accuracy: 0.5000 - val_loss: 1.0051
# Epoch 11/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 30s 34ms/step - accuracy: 0.5634 - loss: 1.1680 - val_accuracy: 0.5477 - val_loss: 1.2283
# Epoch 12/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 15us/step - accuracy: 0.6875 - loss: 0.3412 - val_accuracy: 0.5000 - val_loss: 0.5336
# Epoch 13/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 30s 34ms/step - accuracy: 0.5787 - loss: 1.1363 - val_accuracy: 0.5508 - val_loss: 1.2064
# Epoch 14/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 16us/step - accuracy: 0.5938 - loss: 0.6648 - val_accuracy: 0.6000 - val_loss: 0.4032
# Epoch 15/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 30s 33ms/step - accuracy: 0.5772 - loss: 1.1239 - val_accuracy: 0.5426 - val_loss: 1.1916
# Epoch 16/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 14us/step - accuracy: 0.5625 - loss: 0.6326 - val_accuracy: 0.3000 - val_loss: 0.8800
# Epoch 17/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 30s 33ms/step - accuracy: 0.5860 - loss: 1.1144 - val_accuracy: 0.5718 - val_loss: 1.1469
# Epoch 18/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 14us/step - accuracy: 0.5312 - loss: 0.5891 - val_accuracy: 0.7000 - val_loss: 0.5502
# Epoch 19/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 30s 34ms/step - accuracy: 0.5915 - loss: 1.1062 - val_accuracy: 0.5356 - val_loss: 1.2436
# Epoch 20/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 14us/step - accuracy: 0.6875 - loss: 0.5388 - val_accuracy: 0.5000 - val_loss: 0.6958
# Epoch 21/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 30s 34ms/step - accuracy: 0.5977 - loss: 1.0896 - val_accuracy: 0.5562 - val_loss: 1.1682
# Epoch 22/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 14us/step - accuracy: 0.6562 - loss: 0.4475 - val_accuracy: 0.7000 - val_loss: 0.4379
# Epoch 23/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 30s 34ms/step - accuracy: 0.6051 - loss: 1.0785 - val_accuracy: 0.5748 - val_loss: 1.1441
# Epoch 24/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 15us/step - accuracy: 0.5312 - loss: 0.7570 - val_accuracy: 0.7000 - val_loss: 0.4568
# Epoch 25/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 30s 33ms/step - accuracy: 0.6059 - loss: 1.0655 - val_accuracy: 0.5691 - val_loss: 1.1511
# Epoch 26/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 16us/step - accuracy: 0.6875 - loss: 0.5421 - val_accuracy: 0.2000 - val_loss: 0.7583
# Epoch 27/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 30s 33ms/step - accuracy: 0.6107 - loss: 1.0570 - val_accuracy: 0.5610 - val_loss: 1.2028
# Epoch 28/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 14us/step - accuracy: 0.7188 - loss: 0.4510 - val_accuracy: 0.6000 - val_loss: 0.4387
# Epoch 29/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 30s 33ms/step - accuracy: 0.6125 - loss: 1.0606 - val_accuracy: 0.5406 - val_loss: 1.2384
# Epoch 30/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 14us/step - accuracy: 0.5312 - loss: 0.7839 - val_accuracy: 0.8000 - val_loss: 0.3930
# Epoch 31/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 30s 34ms/step - accuracy: 0.6112 - loss: 1.0648 - val_accuracy: 0.5716 - val_loss: 1.1992
# Epoch 32/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 14us/step - accuracy: 0.4375 - loss: 0.7233 - val_accuracy: 0.5000 - val_loss: 0.7463
# Epoch 33/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 30s 34ms/step - accuracy: 0.6144 - loss: 1.0733 - val_accuracy: 0.5610 - val_loss: 1.2047
# Epoch 34/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 15us/step - accuracy: 0.5625 - loss: 0.5906 - val_accuracy: 0.6000 - val_loss: 0.4351
# Epoch 35/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 30s 34ms/step - accuracy: 0.6104 - loss: 1.0530 - val_accuracy: 0.5716 - val_loss: 1.2352
# Epoch 36/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 15us/step - accuracy: 0.7812 - loss: 0.3356 - val_accuracy: 0.6000 - val_loss: 0.4372
# Epoch 37/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 30s 34ms/step - accuracy: 0.6148 - loss: 1.0670 - val_accuracy: 0.5479 - val_loss: 1.2180
# Epoch 38/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 14us/step - accuracy: 0.5938 - loss: 0.6048 - val_accuracy: 0.4000 - val_loss: 0.7880
# Epoch 39/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 30s 34ms/step - accuracy: 0.6103 - loss: 1.0644 - val_accuracy: 0.5512 - val_loss: 1.1948
# Epoch 40/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 16us/step - accuracy: 0.5938 - loss: 0.4742 - val_accuracy: 0.5000 - val_loss: 0.5579
# Epoch 41/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 30s 34ms/step - accuracy: 0.6104 - loss: 1.0728 - val_accuracy: 0.5166 - val_loss: 1.3464
# Epoch 42/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 15us/step - accuracy: 0.5000 - loss: 0.8094 - val_accuracy: 0.7000 - val_loss: 0.7073
# Epoch 43/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 30s 34ms/step - accuracy: 0.6158 - loss: 1.0737 - val_accuracy: 0.5385 - val_loss: 1.2840
# Epoch 44/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 15us/step - accuracy: 0.5312 - loss: 0.5983 - val_accuracy: 0.6000 - val_loss: 0.7669
# Epoch 45/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 30s 34ms/step - accuracy: 0.6017 - loss: 1.0888 - val_accuracy: 0.5783 - val_loss: 1.1965
# Epoch 46/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 14us/step - accuracy: 0.6250 - loss: 0.4413 - val_accuracy: 0.7000 - val_loss: 0.4993
# Epoch 47/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 31s 34ms/step - accuracy: 0.6050 - loss: 1.0916 - val_accuracy: 0.5776 - val_loss: 1.2646
# Epoch 48/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 14us/step - accuracy: 0.6562 - loss: 0.5244 - val_accuracy: 0.5000 - val_loss: 0.4967
# Epoch 49/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 31s 34ms/step - accuracy: 0.6027 - loss: 1.0926 - val_accuracy: 0.5649 - val_loss: 1.2228
# Epoch 50/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 16us/step - accuracy: 0.6250 - loss: 0.4225 - val_accuracy: 0.8000 - val_loss: 0.4112

# %%
emotion_model.evaluate(validation_generator)
accuracy = emotion_model_info.history['accuracy']
val_accuracy = emotion_model_info.history['val_accuracy']
loss = emotion_model_info.history['loss']
val_loss = emotion_model_info.history['val_loss']
# Out:
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.2540 - loss: 1.8269

# %%
# Accuracy graph
plt.subplot(1, 2, 1)
plt.plot(accuracy, label='accuracy')
plt.plot(val_accuracy, label='val accuracy')
plt.title('Accuracy Graph')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
 
# loss graph
plt.subplot(1, 2, 2)
plt.plot(loss, label='loss')
plt.plot(val_loss, label='val loss')
plt.title('Loss Graph')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
 
plt.show()
