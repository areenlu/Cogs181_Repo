# %%
#!pip install keras
#!pip install tensorflow
#!pip install --upgrade keras tensorflow
#!pip install --upgrade opencv-python

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Flatten, Input
#from keras.optimizers import Adam
#from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers.schedules import ExponentialDecay
import cv2
from keras.models import model_from_json
import numpy as np
from matplotlib import pyplot as plt

# %%
train_data_gen = ImageDataGenerator(rescale=1./255, 
                                    #rotation_range=30,
                                    #shear_range=0.3,
                                    #zoom_range=0.3,
                                    #horizontal_flip=True,
                                    #fill_mode='nearest'
                                   )
validation_data_gen = ImageDataGenerator(rescale=1./255, 
                                    #rotation_range=30,
                                    #shear_range=0.3,
                                    #zoom_range=0.3,
                                    #horizontal_flip=True,
                                    #fill_mode='nearest'
                                    )

train_generator = train_data_gen.flow_from_directory(
    'data/train',
    target_size=(48, 48),
    batch_size=64,
    color_mode="grayscale",
    class_mode='categorical')

validation_generator = validation_data_gen.flow_from_directory(
        'data/test',
        target_size=(48, 48),
        batch_size=64,
        color_mode="grayscale",
        class_mode='categorical')

total_train_samples = train_generator.n
total_validation_samples = validation_generator.n
batch_size = 64
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
emotion_model = Sequential()

emotion_model.add(Input(shape=(48,48,1)))

emotion_model.add(Conv2D(32, kernel_size=(5, 5), activation='relu'))
emotion_model.add(Conv2D(64, kernel_size=(5, 5), activation='relu'))
emotion_model.add(MaxPooling2D(pool_size=(2, 2)))
emotion_model.add(Dropout(0.25))
 
emotion_model.add(Conv2D(128, kernel_size=(5, 5), activation='relu'))
emotion_model.add(MaxPooling2D(pool_size=(2, 2)))
emotion_model.add(Conv2D(128, kernel_size=(5, 5), activation='relu'))
emotion_model.add(MaxPooling2D(pool_size=(2, 2)))
emotion_model.add(Dropout(0.25))
 
emotion_model.add(Flatten())
emotion_model.add(Dense(1024, activation='relu'))
emotion_model.add(Dropout(0.5))
emotion_model.add(Dense(7, activation='softmax'))
 
emotion_model.summary()
 
cv2.ocl.setUseOpenCL(False)
 
initial_learning_rate = 0.001
lr_schedule = ExponentialDecay(initial_learning_rate, decay_steps=100000, 
                               decay_rate=0.96)
 
#optimizer = Adam(learning_rate=lr_schedule, amsgrad=True)
optimizer = RMSprop(learning_rate=initial_learning_rate)
 
emotion_model.compile(loss='categorical_crossentropy', optimizer=optimizer, 
                      metrics=['accuracy'])
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_24 (Conv2D)                   │ (None, 44, 44, 32)          │             832 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_25 (Conv2D)                   │ (None, 40, 40, 64)          │          51,264 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_18 (MaxPooling2D)      │ (None, 20, 20, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_18 (Dropout)                 │ (None, 20, 20, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_26 (Conv2D)                   │ (None, 16, 16, 128)         │         204,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_19 (MaxPooling2D)      │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_27 (Conv2D)                   │ (None, 4, 4, 128)           │         409,728 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_20 (MaxPooling2D)      │ (None, 2, 2, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_19 (Dropout)                 │ (None, 2, 2, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_6 (Flatten)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_12 (Dense)                     │ (None, 1024)                │         525,312 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_20 (Dropout)                 │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 7)                   │           7,175 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,199,239 (4.57 MB)
#  Trainable params: 1,199,239 (4.57 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
emotion_model_info = emotion_model.fit(
    train_generator,
    steps_per_epoch=total_train_samples // batch_size,
    epochs=30,
    validation_data=validation_generator,
    validation_steps=total_validation_samples // batch_size
)
# Out:
# Epoch 1/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 30s 64ms/step - accuracy: 0.2550 - loss: 1.8069 - val_accuracy: 0.4185 - val_loss: 1.4942
# Epoch 2/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 46us/step - accuracy: 0.4844 - loss: 0.7801 - val_accuracy: 0.5000 - val_loss: 0.8055
# Epoch 3/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 29s 64ms/step - accuracy: 0.4295 - loss: 1.4684 - val_accuracy: 0.4967 - val_loss: 1.3119
# Epoch 4/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 31us/step - accuracy: 0.5312 - loss: 0.6867 - val_accuracy: 0.5000 - val_loss: 0.5823
# Epoch 5/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 29s 64ms/step - accuracy: 0.5077 - loss: 1.2894 - val_accuracy: 0.5375 - val_loss: 1.2080
# Epoch 6/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 42us/step - accuracy: 0.5469 - loss: 0.5681 - val_accuracy: 0.6000 - val_loss: 0.6562
# Epoch 7/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 29s 65ms/step - accuracy: 0.5511 - loss: 1.1816 - val_accuracy: 0.5573 - val_loss: 1.1616
# Epoch 8/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 29us/step - accuracy: 0.4844 - loss: 0.6423 - val_accuracy: 0.6000 - val_loss: 0.3992
# Epoch 9/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 29s 65ms/step - accuracy: 0.5788 - loss: 1.1095 - val_accuracy: 0.5652 - val_loss: 1.1439
# Epoch 10/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 32us/step - accuracy: 0.5469 - loss: 0.6159 - val_accuracy: 0.8000 - val_loss: 0.3612
# Epoch 11/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 30s 66ms/step - accuracy: 0.6071 - loss: 1.0446 - val_accuracy: 0.5824 - val_loss: 1.1134
# Epoch 12/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 33us/step - accuracy: 0.5781 - loss: 0.5361 - val_accuracy: 0.5000 - val_loss: 0.7643
# Epoch 13/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 29s 65ms/step - accuracy: 0.6401 - loss: 0.9739 - val_accuracy: 0.5763 - val_loss: 1.1459
# Epoch 14/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 29us/step - accuracy: 0.5625 - loss: 0.5372 - val_accuracy: 0.8000 - val_loss: 0.3829
# Epoch 15/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 28s 63ms/step - accuracy: 0.6574 - loss: 0.9101 - val_accuracy: 0.5758 - val_loss: 1.1700
# Epoch 16/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 33us/step - accuracy: 0.6094 - loss: 0.5564 - val_accuracy: 0.5000 - val_loss: 0.4791
# Epoch 17/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 28s 63ms/step - accuracy: 0.6858 - loss: 0.8594 - val_accuracy: 0.5869 - val_loss: 1.1667
# Epoch 18/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 31us/step - accuracy: 0.6406 - loss: 0.4175 - val_accuracy: 0.4000 - val_loss: 0.7956
# Epoch 19/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 28s 63ms/step - accuracy: 0.7007 - loss: 0.8099 - val_accuracy: 0.5861 - val_loss: 1.2137
# Epoch 20/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 29us/step - accuracy: 0.6406 - loss: 0.4962 - val_accuracy: 0.4000 - val_loss: 0.4904
# Epoch 21/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 29s 64ms/step - accuracy: 0.7203 - loss: 0.7584 - val_accuracy: 0.5763 - val_loss: 1.2859
# Epoch 22/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 31us/step - accuracy: 0.7188 - loss: 0.4118 - val_accuracy: 0.6000 - val_loss: 0.4885
# Epoch 23/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 29s 63ms/step - accuracy: 0.7359 - loss: 0.7221 - val_accuracy: 0.5819 - val_loss: 1.2959
# Epoch 24/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 30us/step - accuracy: 0.6250 - loss: 0.4882 - val_accuracy: 0.9000 - val_loss: 0.1939
# Epoch 25/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 29s 66ms/step - accuracy: 0.7580 - loss: 0.6679 - val_accuracy: 0.5903 - val_loss: 1.2041
# Epoch 26/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 33us/step - accuracy: 0.6406 - loss: 0.4808 - val_accuracy: 0.4000 - val_loss: 0.6984
# Epoch 27/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 29s 64ms/step - accuracy: 0.7622 - loss: 0.6611 - val_accuracy: 0.5932 - val_loss: 1.2608
# Epoch 28/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 33us/step - accuracy: 0.7500 - loss: 0.3101 - val_accuracy: 0.5000 - val_loss: 0.7901
# Epoch 29/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 29s 64ms/step - accuracy: 0.7787 - loss: 0.6177 - val_accuracy: 0.5929 - val_loss: 1.3298
# Epoch 30/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 31us/step - accuracy: 0.7188 - loss: 0.4223 - val_accuracy: 0.8000 - val_loss: 1.1947

# %%
emotion_model.evaluate(validation_generator)
accuracy = emotion_model_info.history['accuracy']
val_accuracy = emotion_model_info.history['val_accuracy']
loss = emotion_model_info.history['loss']
val_loss = emotion_model_info.history['val_loss']
# Out:
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.5806 - loss: 1.3529

# %%
import matplotlib.pyplot as plt
 
# Accuracy graph
plt.subplot(1, 2, 1)
plt.plot(accuracy, label='accuracy')
plt.plot(val_accuracy, label='val accuracy')
plt.title('Accuracy Graph')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
 
# loss graph
plt.subplot(1, 2, 2)
plt.plot(loss, label='loss')
plt.plot(val_loss, label='val loss')
plt.title('Loss Graph')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
 
plt.show()
